# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/Birthday_printer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Adam's age
name="Adam"
print(f"my name is {name}")
print(f"hello {name}")
birthday=input("What is your birthday?")
print(f"wow {name} was born on {birthday}")

#Mom's age
Name="Kemi"
print(f"my name is {Name}")
print(f"hello {Name}")
birthday=input("What is your birthday?")
print(f"wow {Name} was born on {birthday}")

#Joses age
name_joses="joses"
print(f"my name is {name_joses}")
print(f"hello {name_joses}")
birthday=input("What is your birthday?")
print(f"wow {name_joses} was born on {birthday}")


#Dad's age
Name_Dad="paul"
print(f"my name is {Name_Dad}")
print(f"Nice to meet you {Name_Dad}")
birthday=input("What is your birthday?")
print(f"wow {Name_Dad} was born on {birthday}")


#Hero's age
Name_Hero="Hero"
print(f"my name is {Name_Hero}")
print(f"Nice to meet you {Name_Hero}")
birthday=input("What is your birthday?")
print(f"wow {Name_Hero} was born on {birthday}")
# Out:
# my name is Adam
# hello Adam
# wow Adam was born on 12/15/2014
# my name is Kemi
# hello Kemi
# wow Kemi was born on 11/1/1983
# my name is joses
# hello joses
# wow joses was born on 8/28/2015
# my name is paul
# Nice to meet you paul
# wow paul was born on 2/27/1980
# my name is Hero
# Nice to meet you Hero
# wow Hero was born on 3/27/2014
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/Birthday_printer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Adam's age
name="Adam"
print(f"my name is {name}")
print(f"hello {name}")
age=11
age=input("What is your age?")
print(f"wow {name} is {age} years old!")

#Mom's age
Name="Kemi"
print(f"my name is {Name}")
print(f"hello {Name}")
Age=43
age=input("what is your age?")
print(f"wow {Name} is {Age} years old!")

#Joses age
name_joses="joses"
print(f"my name is {name_joses}")
print(f"hello {name_joses}")
age_joses=11
age=input("What is your age?")
print(f"wow {name_joses} is {age_joses} years old!")

#Dad's age
Name_Dad="paul"
print(f"my name is {Name_Dad}")
print(f"Nice to meet you {Name_Dad}")
Age_Dad=46
age=input("how old are you?")
print(f"Wow {Name_Dad} is {Age_Dad} years old!")


#Hero's age
Name_Hero="Hero"
print(f"my name is {Name_Hero}")
print(f"Nice to meet you {Name_Hero}")
Age_Hero=12
age=input("How old are you?")
print(f"Wow {Name_Hero} is {Age_Hero} years old!")
# Out:
# my name is Adam
# hello Adam
# What is your age?11
# wow Adam is 11 years old!
# my name is Kemi
# hello Kemi
# what is your age?43
# wow Kemi is 43 years old!
# my name is joses
# hello joses
# What is your age?11
# wow joses is 11 years old!
# my name is paul
# Nice to meet you paul
# how old are you?46
# Wow paul is 46 years old!
# my name is Hero
# Nice to meet you Hero
# How old are you?12
# Wow Hero is 12 years old!

# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/Checking_age.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=int(input("How old are you?"))
if age>=10:
  if age<=20:
    print("The student is allowed")
  else:
    print("The student is not allowed")
else:
  print("your are still not allowed")
# Out:
# How old are you?23
# The student is not allowed

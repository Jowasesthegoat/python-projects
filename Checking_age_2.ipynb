# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/Checking_age_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Grade_question=str(input("are you in the 10th grade Y/N")).lower()
if Grade_question=="y":
  age=int(input("How old are you?"))
  if age>=10 and age<=20:
    print("The student is allowed")
  else:
    print("The student is not allowed")
else:
  Grade=int(input("What grade are you in"))
  if Grade<10:
    print("Your grade is too low for this class")
  else:
    print("Your grade is too high for this class")
# Out:
# are you in the 10th grade Y/Ny
# How old are you?22
# The student is not allowed

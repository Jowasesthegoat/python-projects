# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/Circumfrence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def circle_circumference():
  radius_input = int(input("Please input the radius of the circle: "))
  circumference = 2 * 3.14 * radius_input
  print(f"The circumference of the circle is", circumference)
  return circumference
circle_circumference()
# Out:
# Please input the radius of the circle: 4
# The circumference of the circle is {25.12}
# 25.12

# %%
# My Daily Routine from 6/16/2026
# Morning Routine
print("I woke up at 8:48 am")
print("Then I read my daily devotional at 9:00 am", end=":)")
print("After that I went to brush my teeth at 9:13")
print("From 9:13 am until 10:00 am I played games and at 10:00 am I ate breakfast")
print("from 10:00 am to 11:00 am I played more games and ate my breakfast and at 11 am it was time for me to make my github \naccount ")
print("It took me about 30 minutes to finish making my github account so from 11:30 am to 1:30 pm I played even more games.")
# Afternoon Routine
print("At 1:30 pm, I went downstairs to eat lunch until 2:00 pm", end=":)")
print("After I finished eating my lunch at 2:00 pm I rewatched the video which took about 45 minutes.")
print("from 2:45 pm to 3:00 pm I read a book.")
print("From 3:00 pm to 5:00 pm I played games and played outside.")
print("From 5:00 pm to 6:00 pm I ate dinner.")
print("At 6:00 pm I had to start getting ready for my soccer game.")
print("At 7:00 pm my game started which we unfortunately lost", end=":(")
print("At 9:00 pm I came back and got ready to go to sleep.")
#Math
print("I played 3 hours 47 minutes in the morning then in the afternoon I played 5 hours including outside so 3 hours 47 minutes + 5 hours = 8 hours and 47 minutes which is", 3.47+5)
# Out:
# I woke up at 8:48 am
# Then I read my daily devotional at 9:00 am:)After that I went to brush my teeth at 9:13
# From 9:13 am until 10:00 am I played games and at 10:00 am I ate breakfast
# from 10:00 am to 11:00 am I played more games and ate my breakfast and at 11 am it was time for me to make my github
# account
# It took me about 30 minutes to finish making my github account so from 11:30 am to 1:30 pm I played even more games.
# At 1:30 pm, I went downstairs to eat lunch until 2:00 pm:)After I finished eating my lunch at 2:00 pm I rewatched the video which took about 45 minutes.
# from 2:45 pm to 3:00 pm I read a book.
# From 3:00 pm to 5:00 pm I played games and played outside.
# From 5:00 pm to 6:00 pm I ate dinner.
# At 6:00 pm I had to start getting ready for my soccer game.
# At 7:00 pm my game started which we unfortunately lost:(At 9:00 pm I came back and got ready to go to sleep.
# ...

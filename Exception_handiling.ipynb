# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/Exception_handiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  age=int(input("Please input your age"))
  if age>18:
    raise ValueError
  else:
    print("Your age is allowed")
except ValueError:
  print("Your age does not fit the party")
# Out:
# Please input your age2
# Your age is allowed

# %%
try:
  num1=int(input("Please input the first number"))
  num2=int(input("Please input the second number"))
  ans=num1/num2
  print(f"The division of {num1} and {num2} is {ans}")
except ValueError:
  print("Please enter an number")
except ZeroDivisionError:
  print("Enter num2 as a non 0 number")
finally:
  print("Bye Bye")
# Out:
# Please input the first number1
# Please input the second numbera
# Please enter an number
# Bye Bye

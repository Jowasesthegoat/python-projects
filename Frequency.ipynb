# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/Frequency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Text="Food Food Pizza Orange Food Bone"
words = Text.split()
frequency = {}
for w in words:
  frequency[w] = frequency.get(w, 0) + 1
for w, count in frequency.items():
  print(f"{w} {count}")
# Out:
# Food 3
# Pizza 1
# Orange 1
# Bone 1

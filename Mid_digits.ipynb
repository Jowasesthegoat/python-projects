# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/Mid_digits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Take an Integer input from the user and store it in 'num'
num=int(input("Please input any number"))
t=num
#Intialize numLen=0 to count the number of digits
numLen=0
#Count the digits using a loop
while t>0:
  numLen+=1
  t=t//10
#Check if the number has at least four digits
if numLen>=4:
 #Find the middle digits
 numLen=int(numLen/2)
  chk=0
  #Variables to store the the middle digits
  midOne=0
  midTwo=0
  #Extract digits from right to left
  while num>0:
   rem=num%10

   if chk==numLen:
     midOne=rem
   elif chk==(numLen-1):
     midTwo=rem
   num=num//10
   chk+=1
  #Multiply the to middle digits
  prod=midOne*midTwo
  #Print the result
  print(f"Product of mid digits {midOne}*{midTwo}={prod}")
else:
 print("It is not a 4 or more thasn 4-digit number")
# Out:
# Please input any number23456
# Product of mid digits 4*5=20

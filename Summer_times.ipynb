# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/Summer_times.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
temp=int(input("Please enter any temperature"))
if temp>=70:
  print("Rohan should wear light and soft clothes")
else:
  print("Rohan should wear a bit thicker clothes")
# Out:
# Please enter any temperature50
# You should wear a bit thicker clothes

# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/Tuple_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
numbers=(2,3,4,5,6)
result=math.prod(numbers)
print("The product is ",result)
# Out:
# The product is  720

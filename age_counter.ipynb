# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/age_counter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  age=int(input("Please Input your age"))
  if age% 2 ==0 :
    print("Your age is even")
  elif age== str:
    raise ValueError
  else:
    print("Your age is odd")
except ValueError:
  print("Please input your age in numbers")
# Out:
# Please Input your agef
# Please input your age in numbers

# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/lowercase-congratulations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Rams congratulations message.
ram=input("Please type congratulations to ram's friend in lowercase.")
print(ram.upper())
# Out:
# Please type congratulations to ram's friend in lowercase.congratulations
# CONGRATULATIONS

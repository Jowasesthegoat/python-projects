# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/power_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#power calculator
num=int(input("Please enter any number"))
power=int(input("Please enter how many times you want it to be raised by"))
for i in range(1,power+1):
 calculator= num**i
 print(f"The power of {num} and {i} is {calculator} ")
# Out:
# Please enter any number14
# Please enter how many times you want it to be raised by5
# The power of 14 and 1 is 14
# The power of 14 and 2 is 196
# The power of 14 and 3 is 2744
# The power of 14 and 4 is 38416
# The power of 14 and 5 is 537824

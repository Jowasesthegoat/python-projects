# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/shutdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Getting answers
ans=input("Please input Y/N")
def shut_down():
  if ans=="Y" :
      print("Shutting down computer")
  elif ans=="N":
    print("Not shutting down computer")
  else:
    print("Please input Y/N")
#Calling function
shut_down()
# Out:
# Please input Y/NB
# Please input Y/N

# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-projects/blob/main/total_digits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#total digits
num=int(input("please insert any number: "))
digit=0
while num>0:
  num=num//10
  digit+=1
print(f"the digits for the number is {digit}")
# Out:
# please insert any number: 12345
# the digits for the number is 5
